# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
notebook_path = os.path.abspath(os.path.join(os.getcwd(), '../notebooks'))
input_file_path = rf'{notebook_path}\data\processed'

# %%
# Step 1: Load the Data
year = "2023"
ccy = "gbpusd"
file_path = rf'{input_file_path}/{year}_{ccy}_tick_prev_price_as_base.csv'

# Load the dataset
df = pd.read_csv(file_path)
df["datetime"] = pd.to_datetime(df["datetime"])

# Step 2: Feature Engineering

# Create lagged features
lags = [1, 2, 3, 5, 10]
for lag in lags:
    df[f'lag_{lag}'] = df['price'].shift(lag)

# Rolling mean and standard deviation
rolling_windows = [5, 10, 20]
for window in rolling_windows:
    df[f'rolling_mean_{window}'] = df['price'].rolling(window=window).mean()
    df[f'rolling_std_{window}'] = df['price'].rolling(window=window).std()

# Exponential moving averages (EMA)
ema_spans = [5, 10, 20]
for span in ema_spans:
    df[f'ema_{span}'] = df['price'].ewm(span=span, adjust=False).mean()

# Momentum indicators
df['roc'] = (df['price'] - df['price'].shift(5)) / df['price'].shift(5) * 100  # Rate of Change
df['rsi'] = 100 - (100 / (1 + (df['price'].diff().clip(lower=0).rolling(14).mean() /
                               df['price'].diff().clip(upper=0).abs().rolling(14).mean())))

# Drop missing values caused by rolling/lagging
df.dropna(inplace=True)

# Define features and target
features = [col for col in df.columns if col.startswith(('lag_', 'rolling_', 'ema_', 'roc', 'rsi'))]
df['target'] = (df['directions'] > 0).astype(int)  # Binary target: 1 for up, 0 for down
X = df[features]
y = df['target']

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: TimeSeriesSplit for Train-Test Splitting
tscv = TimeSeriesSplit(n_splits=5)

# Prepare for storing results
accuracies = []
conf_matrices = []
classification_reports = []

# Step 4: Train and Evaluate Model
for train_index, test_index in tscv.split(X_scaled):
    # Train-test split
    X_train, X_test = X_scaled[train_index], X_scaled[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Define Neural Network Model
    model = Sequential([
        Dense(64, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        Dropout(0.3),
        Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        Dropout(0.3),
        Dense(1, activation='sigmoid')  # Sigmoid for binary classification
    ])

    # Compile the Model
    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # Train the Model
    history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2, verbose=1)

    # Evaluate the Model
    y_pred_probs = model.predict(X_test)
    y_pred = (y_pred_probs > 0.5).astype(int).flatten()  # Convert probabilities to binary labels

    # Collect Metrics
    accuracy = accuracy_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    classification_report_text = classification_report(y_test, y_pred)

    accuracies.append(accuracy)
    conf_matrices.append(conf_matrix)
    classification_reports.append(classification_report_text)

    print(f"Fold Accuracy: {accuracy}")
    print(f"Confusion Matrix:\n{conf_matrix}")
    print(f"Classification Report:\n{classification_report_text}")

# Step 5: Display Average Results
avg_accuracy = np.mean(accuracies)
print(f"\nAverage Accuracy Across Folds: {avg_accuracy}")

# Step 6: Plot Training History (from last fold)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Model Training History (Last Fold)')
plt.show()
# Out:
# Epoch 1/20
# c:\Users\mmori\Documents\fx_strategy_project\fx_strategy_env\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5260 - loss: 1.3614 - val_accuracy: 0.6584 - val_loss: 1.2083
# Epoch 2/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6815 - loss: 1.1548 - val_accuracy: 0.6626 - val_loss: 1.0830
# Epoch 3/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6839 - loss: 0.6140 - val_accuracy: 0.6952 - val_loss: 0.5965
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7091 - loss: 0.5935 - val_accuracy: 0.6924 - val_loss: 0.5920
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6953 - loss: 0.5972 - val_accuracy: 0.6979 - val_loss: 0.5935
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7047 - loss: 0.5829 - val_accuracy: 0.6993 - val_loss: 0.5888
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6880 - loss: 0.6037 - val_accuracy: 0.6966 - val_loss: 0.5897
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7027 - loss: 0.5869 - val_accuracy: 0.6952 - val_loss: 0.5872
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold Accuracy: 0.700082850041425
# Confusion Matrix:
# [[455 152]
#  [210 390]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.75      0.72       607
#            1       0.72      0.65      0.68       600
#
#     accuracy                           0.70      1207
#    macro avg       0.70      0.70      0.70      1207
# weighted avg       0.70      0.70      0.70      1207
#
# Epoch 1/20
# c:\Users\mmori\Documents\fx_strategy_project\fx_strategy_env\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5985 - loss: 1.2368 - val_accuracy: 0.6608 - val_loss: 0.9442
# Epoch 2/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6762 - loss: 0.8887 - val_accuracy: 0.6556 - val_loss: 0.7825
# Epoch 3/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6693 - loss: 0.7665 - val_accuracy: 0.6846 - val_loss: 0.6920
# Epoch 4/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6934 - loss: 0.6861 - val_accuracy: 0.6846 - val_loss: 0.6547
# Epoch 5/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6991 - loss: 0.6497 - val_accuracy: 0.6846 - val_loss: 0.6290
# Epoch 6/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6801 - loss: 0.6488 - val_accuracy: 0.6949 - val_loss: 0.6190
# Epoch 7/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6994 - loss: 0.6215 - val_accuracy: 0.6918 - val_loss: 0.6178
# Epoch 8/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6868 - loss: 0.6155 - val_accuracy: 0.6908 - val_loss: 0.6050
# Epoch 9/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7016 - loss: 0.5987 - val_accuracy: 0.6908 - val_loss: 0.5974
# Epoch 10/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6956 - loss: 0.6111 - val_accuracy: 0.6939 - val_loss: 0.5956
# Epoch 11/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6958 - loss: 0.6137 - val_accuracy: 0.6856 - val_loss: 0.5907
# Epoch 12/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6959 - loss: 0.6012 - val_accuracy: 0.6918 - val_loss: 0.5927
# Epoch 13/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6951 - loss: 0.6015 - val_accuracy: 0.6887 - val_loss: 0.5865
# Epoch 14/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6980 - loss: 0.5951 - val_accuracy: 0.7042 - val_loss: 0.5896
# Epoch 15/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6849 - loss: 0.6116 - val_accuracy: 0.6960 - val_loss: 0.6040
# Epoch 16/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7133 - loss: 0.5851 - val_accuracy: 0.7073 - val_loss: 0.5903
# Epoch 17/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7149 - loss: 0.5894 - val_accuracy: 0.7073 - val_loss: 0.5799
# Epoch 18/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7078 - loss: 0.5883 - val_accuracy: 0.7011 - val_loss: 0.5780
# Epoch 19/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7090 - loss: 0.5911 - val_accuracy: 0.6939 - val_loss: 0.5814
# Epoch 20/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7002 - loss: 0.5995 - val_accuracy: 0.6970 - val_loss: 0.5726
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold Accuracy: 0.6951118475559238
# Confusion Matrix:
# [[434 187]
#  [181 405]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.70      0.70       621
#            1       0.68      0.69      0.69       586
#
#     accuracy                           0.70      1207
#    macro avg       0.69      0.69      0.69      1207
# weighted avg       0.70      0.70      0.70      1207
#
# Epoch 1/20
# c:\Users\mmori\Documents\fx_strategy_project\fx_strategy_env\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5859 - loss: 1.2311 - val_accuracy: 0.6755 - val_loss: 0.9137
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6790 - loss: 0.8631 - val_accuracy: 0.6821 - val_loss: 0.7549
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6814 - loss: 0.7313 - val_accuracy: 0.6805 - val_loss: 0.6838
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6824 - loss: 0.6727 - val_accuracy: 0.6805 - val_loss: 0.6484
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6844 - loss: 0.6449 - val_accuracy: 0.6780 - val_loss: 0.6295
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7027 - loss: 0.6248 - val_accuracy: 0.6788 - val_loss: 0.6230
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6946 - loss: 0.6128 - val_accuracy: 0.6846 - val_loss: 0.6125
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6959 - loss: 0.6013 - val_accuracy: 0.6846 - val_loss: 0.6062
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6922 - loss: 0.6091 - val_accuracy: 0.6863 - val_loss: 0.6034
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7013 - loss: 0.5922 - val_accuracy: 0.6854 - val_loss: 0.5996
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6950 - loss: 0.5990 - val_accuracy: 0.6871 - val_loss: 0.5975
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7059 - loss: 0.5957 - val_accuracy: 0.6821 - val_loss: 0.5956
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7023 - loss: 0.5933 - val_accuracy: 0.6871 - val_loss: 0.5937
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7058 - loss: 0.5925 - val_accuracy: 0.6887 - val_loss: 0.5945
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7119 - loss: 0.5812 - val_accuracy: 0.6863 - val_loss: 0.5916
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6985 - loss: 0.5917 - val_accuracy: 0.6887 - val_loss: 0.5939
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7039 - loss: 0.5931 - val_accuracy: 0.6896 - val_loss: 0.5865
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6952 - loss: 0.5894 - val_accuracy: 0.6954 - val_loss: 0.5864
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7024 - loss: 0.5831 - val_accuracy: 0.6937 - val_loss: 0.5866
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7153 - loss: 0.5873 - val_accuracy: 0.6954 - val_loss: 0.5805
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold Accuracy: 0.6934548467274234
# Confusion Matrix:
# [[387 191]
#  [179 450]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.67      0.68       578
#            1       0.70      0.72      0.71       629
#
#     accuracy                           0.69      1207
#    macro avg       0.69      0.69      0.69      1207
# weighted avg       0.69      0.69      0.69      1207
#
#
# Average Accuracy Across Folds: 0.6941176470588235

# %%
def backtest_strategy(df, y_pred, transaction_cost=0):
    """
    Perform backtesting on a dataset based on model predictions.
    
    Parameters:
        df (pd.DataFrame): DataFrame containing price data and other features.
        y_pred (np.array or list): Model predictions (0 or 1) for the target.
        transaction_cost (float): Cost per trade as a fraction of price (default is 0).

    Returns:
        dict: Backtesting results including metrics and cumulative returns.
    """
    df = df.copy()  # Avoid modifying the original DataFrame

    # Step 1: Add Predictions to DataFrame
    df['predicted_signal'] = 0  # Initialize column
    df.loc[df.index[-len(y_pred):], 'predicted_signal'] = y_pred  # Add predictions to the test period

    # Step 2: Generate Trading Signals
    # Buy (1) if predicted_signal == 1, Sell (-1) if predicted_signal == 0
    df['position'] = df['predicted_signal'].apply(lambda x: 1 if x == 1 else -1)

    # Step 3: Calculate Returns
    df['price_change'] = df['price'].diff()  # Price change
    df['strategy_return'] = df['position'].shift(1) * df['price_change']  # Strategy returns
    if transaction_cost > 0:
        # Subtract transaction costs
        trades = df['position'].diff().abs()  # Count trades (1 for every position change)
        df['strategy_return'] -= trades * transaction_cost

    # Step 4: Calculate Cumulative Returns
    df['cumulative_strategy_return'] = df['strategy_return'].cumsum()
    df['cumulative_market_return'] = df['price_change'].cumsum()

    # Step 5: Calculate Metrics
    total_return = df['strategy_return'].sum()
    win_rate = (df['strategy_return'] > 0).mean()
    sharpe_ratio = df['strategy_return'].mean() / (df['strategy_return'].std() + 1e-10)  # Avoid division by zero
    drawdown = (df['cumulative_strategy_return'].cummax() - df['cumulative_strategy_return']).max()

    # Step 6: Plot Results
    plt.figure(figsize=(10, 6))
    plt.plot(df['cumulative_strategy_return'], label='Strategy Return')
    plt.plot(df['cumulative_market_return'], label='Market Return')
    plt.xlabel('Time')
    plt.ylabel('Cumulative Returns')
    plt.legend()
    plt.title('Backtesting Results')
    plt.show()

    # Return Results
    results = {
        "Total Return": total_return,
        "Win Rate": win_rate,
        "Sharpe Ratio": sharpe_ratio,
        "Max Drawdown": drawdown
    }
    return results

# %%
# Assuming `df` is your DataFrame and `y_pred` is the model's predictions
results = backtest_strategy(df, y_pred, transaction_cost=0.001)  # Adjust transaction_cost as needed

# Print Backtesting Metrics
print(f"Total Return: {results['Total Return']}")
print(f"Win Rate: {results['Win Rate']:.2%}")
print(f"Sharpe Ratio: {results['Sharpe Ratio']:.2f}")
print(f"Max Drawdown: {results['Max Drawdown']:.2f}")
# Out:
# Total Return: -0.4490000000000045
# Win Rate: 50.08%
# Sharpe Ratio: -0.05
# Max Drawdown: 0.48

# %% [markdown]
# Backtesting

# %% [markdown]
# Parameters:
#
# initial_balance: The starting capital for the backtest.
# lot_size: The size of each trade (in units of the currency).
# Logic:
#
# A trade is placed based on the model's prediction:
# If the model predicts "up" (1), we simulate a buy.
# If the model predicts "down" (0), we simulate a sell.
# Profit or loss is calculated based on whether the model's prediction aligns with the actual movement (y_test).
# Trade Profit Calculation:
#
# price * 0.0001 * lot_size is a simple approximation for pip movement profit/loss.
# This assumes 1 pip = 0.0001 for most currency pairs (adjust as needed).
# Outputs:
#
# balance_history: The account balance over time.
# trade_log: Detailed log of each trade, including tick, price, predicted and actual direction, profit, and updated balance.
